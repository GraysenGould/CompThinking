# %%
# query occurs in the middle
tests = []
tests.append({
    'input': {
        'cards': [13, 11, 10, 7, 4, 3, 1, 0],
        'query': 1
    },
    'output': 6
})
# query is the first element
tests.append({
    'input': {
        'cards': [4, 2, 1, -1],
        'query': 4
    },
    'output': 0
})
# query is the last element
tests.append({
    'input': {
        'cards': [3, -1, -9, -127],
        'query': -127
    },
    'output': 3
})
# cards contains just one element, query
tests.append({
    'input': {
        'cards': [6],
        'query': 6
    },
    'output': 0 
})
# cards does not contain query 
tests.append({
    'input': {
        'cards': [9, 7, 5, 2, -9],
        'query': 4
    },
    'output': -1
})
# cards is empty
tests.append({
    'input': {
        'cards': [],
        'query': 7
    },
    'output': -1
})
# numbers can repeat in cards
tests.append({
    'input': {
        'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
        'query': 3
    },
    'output': 7
})
# query occurs multiple times
tests.append({
    'input': {
        'cards': [8, 8, 6, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
        'query': 6
    },
    'output': 2
})
tests.append({
    'input': {
        'cards': [5,7,7,8,8,10],
        'query': 8
    },
    'output': 3
})

# %%
print(len(tests))
# Out:
# 9

# %%
# brute force
def get_position(cards, query):
    pos = -1
    for i in range(len(cards)):
        if cards[i] == query:
            pos = i
    return pos

# %%
print(get_position([0],7))
# Out:
# -1

# %%
def binary_search (cards, query):
    pos = -1
    bound = [0,len(cards) -1]

    
    while bound[0] <= bound[1]:
        midpoint = sum(bound)//2
        #print(f" debug: midpoint: {midpoint}, bound: {bound}")
        if cards[midpoint] == query:
            if midpoint != 0:
                while cards[midpoint - 1] == query:
                    midpoint -= 1
            #search down list to find first occurance of element
            #more code will go here later
            return midpoint
        elif cards[midpoint] > query:
            bound[0] = midpoint + 1
        else:
            bound[1] = midpoint - 1
    return -1

 
    
            

#my solution
#use interval (a list), spanning whole array
#take the average of the two values, use integer division
#check whether this value is equal to, greater than, or less than query
#if equal, return position
#else, set average to left or right bound
#repeat

# %%
for i in tests:
    current_test = i["input"]
    print(f"Test Case: {current_test}")
    solution = binary_search(**current_test)
    print(f"My awnswer: {solution}")
    print(f"Passed: {i["output"] == solution} \n\n")
# Out:
# Test Case: {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}
# My awnswer: 6
# Passed: True
#
#
# Test Case: {'cards': [4, 2, 1, -1], 'query': 4}
# My awnswer: 0
# Passed: True
#
#
# Test Case: {'cards': [3, -1, -9, -127], 'query': -127}
# My awnswer: 3
# Passed: True
#
#
# Test Case: {'cards': [6], 'query': 6}
# My awnswer: 0
# Passed: True
#
#
# Test Case: {'cards': [9, 7, 5, 2, -9], 'query': 4}
# My awnswer: -1
# Passed: True
#
#
# Test Case: {'cards': [], 'query': 7}
# My awnswer: -1
# Passed: True
#
#
# Test Case: {'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 3}
# My awnswer: 7
# Passed: True
#
#
# Test Case: {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 6}
# My awnswer: 2
# Passed: True
#
#
# Test Case: {'cards': [5, 7, 7, 8, 8, 10], 'query': 8}
# My awnswer: -1
# Passed: False

# %%
#try 2
def binary_search (cards, query):
    pos = -1
    scope = len(cards)
    direction = "right"
    guess = round(scope // 2 - 1)
    
    while scope != 0:
        print(guess)
        if cards[guess] == query:
            return guess
        elif cards[guess] > guess:
            direction = "left"
            scope = scope / 2
            guess = round(guess - scope/2)
        else:
            direction = "right"
            scope = scope / 2
            guess = round(guess + scope//2)

# %% [markdown]
# ## leetcode - find beginning and end of numers in array:

# %%
tests = []
tests.append({
    'input': {
        'cards': [8, 8, 6, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
        'query': 6
    },
    'output': 2
})
tests.append({
    'input': {
        'cards': [5,7,7,8,8,10],
        'query': 8
    },
    'output': 3
})
tests.append({
    'input': {
        'cards': [5,7,7,8,8,10],
        'query': 6
    },
    'output': -1
})

tests.append({
    'input': {
        'cards': [],
        'query': 0
    },
    'output': -1
})

# %%
def binary_search(lo, hi, condition):
    while lo <= hi:
        mid = (lo + hi) // 2
        result = condition(mid) 
        if result == "found":
            return mid
        elif result == "left":
            hi = mid - 1
        else:
            lo = mid + 1
    return -1

def first_position(nums, target): 
    def condition(mid):
        if nums[mid] == target:
            if mid > 0 and nums[mid - 1] == target:
                return 'left'
            return 'found'
        elif nums[mid] < target:
            return 'right'
        else:
            return 'left'
    return binary_search(0, len(nums) - 1, condition)
    
def first_position(nums, target): 
    def condition(mid):
        if nums[mid] == target:
            if mid < len(nums) -1 and nums[mid+1] == target:
                return "right"
            return 'found'
        elif nums[mid] < target:
            return 'right'
        else:
            return 'left'
    return binary_search(0, len(nums) - 1, condition)

def first_and_last_position(nums, target):
    return first_position(nums, target), last_position(nums, target)

# %%
first_and_last_position(tests[1]["input"]["cards"], tests[1]["input"]["query"])
# Out:
# (4, 4)

# %% [raw]
# Example 1:
#
# Input: nums = [5,7,7,8,8,10], target = 8
# Output: [3,4]
# Example 2:
#
# Input: nums = [5,7,7,8,8,10], target = 6
# Output: [-1,-1]
# Example 3:
#
# Input: nums = [], target = 0
# Output: [-1,-1]

# %%
#try 1

def binary_search_left (cards, query):
    pos = -1
    bound = [0,len(cards) -1]

    
    while bound[0] <= bound[1]:
        midpoint = sum(bound)//2
        #print(f" debug: midpoint: {midpoint}, bound: {bound}")
        if cards[midpoint] == query:
            if midpoint != 0 and cards[midpoint - 1] == query:
                bound[1] = midpoint -1
                continue
            #search down list to find first occurance of element
            #more code will go here later
            return midpoint
        elif cards[midpoint] > query:
            bound[0] = midpoint + 1
        else:
            bound[1] = midpoint - 1
    return -1
    
def binary_search_right (cards, query):
    pos = -1
    bound = [0,len(cards) -1]

    
    while bound[0] <= bound[1]:
        midpoint = sum(bound)//2
        #print(f" debug: midpoint: {midpoint}, bound: {bound}")
        if cards[midpoint] == query:
            """
            if midpoint != 0:
                while cards[midpoint - 1] == query:
                    midpoint -= 1
            """
            if midpoint < len(cards) - 1 and cards[midpoint + 1] == query:
                bound[0] = midpoint + 1
                continue
            #search down list to find first occurance of element
            #more code will go here later
            return midpoint
        elif cards[midpoint] > query:
            bound[0] = midpoint + 1
        else:
            bound[1] = midpoint - 1
    return -1

# %%
print(tests[1])

sol = (binary_search_left(**tests[1]["input"]), binary_search_right(**tests[1]["input"]))
print(sol)
# Out:
# {'input': {'cards': [5, 7, 7, 8, 8, 10], 'query': 8}, 'output': 3}
# (-1, -1)

# %%
for i in tests:
    current_test = i["input"]
    print(current_test)
    sol = (binary_search_left(**current_test), binary_search_right(**current_test))
    print(sol)
# Out:
# {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 6}
# (2, 7)
# {'cards': [5, 7, 7, 8, 8, 10], 'query': 8}
# (-1, -1)
# {'cards': [5, 7, 7, 8, 8, 10], 'query': 6}
# (-1, -1)
# {'cards': [], 'query': 0}
# (-1, -1)
