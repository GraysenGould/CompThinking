# %%
class TreeNode:
    def __init__ (self, key):
        self.key = key
        self.left = None
        self.right = None

# %%
# creating nodes 
node0 = TreeNode(3)
node1 = TreeNode(4)
node2 = TreeNode(5)

# %%
node0.key
# Out:
# 3

# %%
node0.right = node1
node1.left = node2

# %%
node0.right.key, node1.left.key #check the keys of the left right
# Out:
# (4, 5)

# %%
# Create Binary Key
binary_tree = TreeNode(2)

#left side 
binary_tree.left = TreeNode(3)
binary_tree.left.left = TreeNode(1)

#right side
binary_tree.right = TreeNode(5)
binary_tree.right.left = TreeNode(3)
binary_tree.right.left.right = TreeNode(4)

#far right
binary_tree.right.right = TreeNode(7)
binary_tree.right.right.left = TreeNode(6)
binary_tree.right.right.right = TreeNode(8)

# %%
binary_tree.right.left.right.key
# Out:
# 4

# %%
def get_nodes (tree):
    if tree.right:
        print(tree.key, "on right")
        get_nodes(tree.right)
    if tree.left:
        print(tree.key, "on left")
        get_nodes(tree.right)
get_nodes(binary_tree)
# Out:
# 2 on right
# 5 on right
# 7 on right
# 7 on left
# 5 on left
# 7 on right
# 7 on left
# 2 on left
# 5 on right
# 7 on right
# 7 on left
# 5 on left
# 7 on right
# 7 on left

# %%
tree_tuple = ((1,3, None), 2, ((None, 3, 4), 5, (6, 7, 8)))

# %%
def parse_tuple (data):
    if isinstance(data, tuple) and len(data) == 3:
        node = TreeNode(data[1])
        node.left = parse_tuple(data[0])
        node.right = parse_tuple(data[2])
    elif data is None:
        node = None
    else:
        node = TreeNode(data)
    return node

# %%
binary_tree2 = parse_tuple(tree_tuple)

# %%
binary_tree2.right.left.right.key
# Out:
# 4

# %%
#function to print a binary tree
def print_tree (tree, level):
    print(f"{tree.key} found at level {level}")
    if tree.left != None:
        print("On left:", end = "")
        print_tree(tree.left, level +1)
    if tree.right != None:
        print("On right:", end = "")
        print_tree(tree.right, level +1)
print_tree(binary_tree2, 0)
# Out:
# 2 found at level 0
# On left:3 found at level 1
# On left:1 found at level 2
# On right:5 found at level 1
# On left:3 found at level 2
# On right:4 found at level 3
# On right:7 found at level 2
# On left:6 found at level 3
# On right:8 found at level 3

# %%
# fucntion to get back to our tuple
def get_tuple (node):
    left = None
    right = None
    key = node.key
    if node.left:
        left = get_tuple(node.left)
    if node.right:
        right = get_tuple(node.right)
        
    if left != None or right != None:
        return (left, key, right)
    else:
        return key
print(get_tuple(binary_tree2))
# Out:
# ((1, 3, None), 2, ((None, 3, 4), 5, (6, 7, 8)))

# %%
# in order traversal

def traverse_tree (node):
    if node is None:
        return []
    else:
        return (traverse_tree(node.left) + [node.key] + traverse_tree(node.right))
traverse_tree(binary_tree2)
# Out:
# [1, 3, 2, 3, 4, 5, 6, 7, 8]

# %%
print ([8] + [9] + [10])
# Out:
# [8, 9, 10]

# %%
# find height of tree
def tree_height (tree):
    if tree is None:
        return 0
    return 1 + max(tree_height(tree.right), tree_height(tree.left))
tree_size(binary_tree2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       4         return 0
#       5     return 1 + max(tree_height(tree.right), tree_height(tree.left))
# ----> 6 tree_size(binary_tree2)
#
# NameError: name 'tree_size' is not defined

# %%
# get number of nodes

def tree_size (node):
    if node is None:
        return 0
    return 1 + tree_size(node.left) + tree_size(node.right)
tree_size(binary_tree2)

# %%
# encapsulation of functionality
class TreeNode:
    def __init__ (self, key):
        self.key = key
        self.left = None
        self.right = None
    def size (self):
        if self is None:
            return 0
        return 1 + self.size(self.left) + self.size(self.right)
        
    def height (self):
        if self is None:
            return 0
        return 1 + max(self.height(self.right), self.height(self.left))
        
    def traverse (self):
        if self is None:
            return []
        else:
            return (self.traverse(self.left) + [self.key] + self.traverse(self.right))
            
    def get_tuple (self):
        left = None
        right = None
        key = self.key
        if self.left:
            left = self.get_tuple(self.left)
        if self.right:
            right = self.get_tuple(self.right)
            
        if left != None or right != None:
            return (left, key, right)
        else:
            return key

# %% [markdown]
# ## Getting Back Into It

# %%
class TreeNode():
    def __init__(self, key):
        self.key, self.left, self.right = key, None, None
    
    def height(self):
        if self is None:
            return 0
        return 1 + max(TreeNode.height(self.left), TreeNode.height(self.right))
    
    def size(self):
        if self is None:
            return 0
        return 1 + TreeNode.size(self.left) + TreeNode.size(self.right)

    def traverse_in_order(self):
        if self is None: 
            return []
        return (TreeNode.traverse_in_order(self.left) + 
                [self.key] + 
                TreeNode.traverse_in_order(self.right))
    
    def display_keys(self, space='\t', level=0):
        # If the node is empty
        if self is None:
            print(space*level + '∅')
            return   

        # If the node is a leaf 
        if self.left is None and self.right is None:
            print(space*level + str(self.key))
            return

        # If the node has children
        display_keys(self.right, space, level+1)
        print(space*level + str(self.key))
        display_keys(self.left,space, level+1)    
    
    def to_tuple(self):
        if self is None:
            return None
        if self.left is None and self.right is None:
            return self.key
        return TreeNode.to_tuple(self.left),  self.key, TreeNode.to_tuple(self.right)
    
    def __str__(self):
        return "BinaryTree <{}>".format(self.to_tuple())
    
    def __repr__(self):
        return "BinaryTree <{}>".format(self.to_tuple())
    
    @staticmethod    
    def parse_tuple(data):
        if data is None:
            node = None
        elif isinstance(data, tuple) and len(data) == 3:
            node = TreeNode(data[1])
            node.left = TreeNode.parse_tuple(data[0])
            node.right = TreeNode.parse_tuple(data[2])
        else:
            node = TreeNode(data)
        return node

# %%
tree1 = TreeNode.parse_tuple(((1, 3, None), 2, ((None, 3, 4), 5, (6, 7, 8))))
tree2 = TreeNode.parse_tuple((('aakash', 'biraj', 'hemanth')  , 'jadhesh', ('siddhant', 'sonaksh', 'vishal')))
tree3 = TreeNode.parse_tuple(((4,6,7),9,(11,12,13)))

# %%
# if left node is less - only if left node exists
# if right node is more - only right node exists

# %%
def is_bst (node):
    bst_left = True
    bst_right = True
    if node:
        if node.left and node.left.key:
            bst_left = node.left.key < node.key and is_bst(node.left)
        if node.right and node.right.key:
            bst_right = node.right.key > node.key and is_bst(node.right)
    else:
        return True
    return bst_right and bst_left

# %%
def bst_max(node):
    if isinstance(node, int):
        return node
    if not node:
        return 0
    return max(bst_max(node.right), node.key, bst_max(node.left))
    
def bst_min(node):
    if isinstance(node, int):
        return node
    if not node:
        return 0
    print(node.right, node.key, node.right)
    return min(bst_max(node.right), node.key, bst_max(node.left))

# %%
bst_min(tree2)
# Out:
# BinaryTree <('siddhant', 'sonaksh', 'vishal')> jadhesh BinaryTree <('siddhant', 'sonaksh', 'vishal')>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 bst_min(tree2)
#
# Cell In[22], line 14, in bst_min(node)
#      12     return 0
#      13 print(node.right, node.key, node.right)
# ---> 14 return min(bst_max(node.right), node.key, bst_max(node.left))
#
# Cell In[22], line 6, in bst_max(node)
#       4 if not node:
#       5     return 0
# ----> 6 return max(bst_max(node.right), node.key, bst_max(node.left))
#
# Cell In[22], line 6, in bst_max(node)
#       4 if not node:
#       5     return 0
# ----> 6 return max(bst_max(node.right), node.key, bst_max(node.left))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
is_bst(tree3)
# Out:
# True

# %%
def is_bst (node):
    #check if left less than, right greater than
    #node.left < node.key
    #node.right > node.key
    if node:
        is_bst_node = (node.left.key < node.key) and (node.right.key > node.key)
    else:
        return True
    if node and node.left:
        
        is_bst_left = is_bst(node.left)
    else:
        return True
    if node and node.right:
        is_bst_right = is_bst(node.right)
    else:
        return True
    return is_bst_node and is_bst_left and is_bst_right

# %%
is_bst(tree1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 is_bst(tree1)
#
# Cell In[25], line 11, in is_bst(node)
#       8     return True
#       9 if node and node.left:
# ---> 11     is_bst_left = is_bst(node.left)
#      12 else:
#      13     return True
#
# Cell In[25], line 6, in is_bst(node)
#       1 def is_bst (node):
#       2     #check if left less than, right greater than
#       3     #node.left < node.key
#       4     #node.right > node.key
#       5     if node:
# ----> 6         is_bst_node = (node.left.key < node.key) and (node.right.key > node.key)
#       7     else:
#       8         return True
#
# AttributeError: 'NoneType' object has no attribute 'key'

# %%
def bst_max (node):
    left = right = node.key
    if isinstance(node.left,TreeNode):
        left = max(bst_max(node.left.key), node.key)
    if isinstance(node.right,TreeNode):
        right = max(bst_max(node.right.key), node.key)
    return max(right, left)

# %% [markdown]
# # Binary search trees

# %%
class User:
    def __init__(self, username, name, email):
        self.username = username
        self.name = name
        self.email = email
        
    def __repr__(self):
        return "User(username='{}', name='{}', email='{}')".format(self.username, self.name, self.email)
    
    def __str__(self):
        return self.__repr__()

# %%
aakash = User('aakash', 'Aakash Rai', 'aakash@example.com')
biraj = User('biraj', 'Biraj Das', 'biraj@example.com')
hemanth = User('hemanth', 'Hemanth Jain', 'hemanth@example.com')
jadhesh = User('jadhesh', 'Jadhesh Verma', 'jadhesh@example.com')
siddhant = User('siddhant', 'Siddhant Sinha', 'siddhant@example.com')
sonaksh = User('sonaksh', 'Sonaksh Kumar', 'sonaksh@example.com')
vishal = User('vishal', 'Vishal Goel', 'vishal@example.com')

# %%
class BSTNode ():
    def __init__ (self, key, value = None):
        self.key = key
        self.value = value
        self.left = None
        self.right = None
        self.parent = None

# %%
#level 0
tree = BSTNode(jadhesh.username, jadhesh)
tree.key, tree.value
# Out:
# ('jadhesh',
#  User(username='jadhesh', name='Jadhesh Verma', email='jadhesh@example.com'))

# %%
# level 1
tree.left = BSTNode(biraj.username, biraj)
tree.left.parent = tree
tree.right = BSTNode(sonaksh.username, sonaksh)
tree.right.parent = tree

# %%
#level 2 left
current_node = tree.left 
current_node.left = BSTNode(aakash.username, aakash)
current_node.left.parent = current_node
current_node.right = BSTNode(hemanth.username, hemanth)
current_node.right.parent = current_node

# %%
# level 2 right
current_node = tree.right 
current_node.left = BSTNode(siddhant.username, siddhant)
current_node.left.parent = current_node
current_node.right = BSTNode(vishal.username, vishal)
current_node.right.parent = current_node

# %%
#insertion into BST

# %% [markdown]
# <img src="https://i.imgur.com/lVqP63n.png" width="520">

# %%
new_key = "Tonya"
def insert_key (node, key, value):
# Out:
#   Cell In[36], line 3
#
#     ^
# SyntaxError: incomplete input
