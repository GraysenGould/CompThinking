# %% [markdown]
# Topics covered:
# 1. grouping of rows based on identical columns values
#
#
# 2. creating data and time data, and handling date and time data
#
#
# 3. Exporting dataframes

# %%
import pandas as p
import numpy as n

# %% [markdown]
# # 1. grouping

# %% [markdown]
# Let's find the statewise average scores by students from the dataframe below:

# %%
mydata={"Name":["Harry","Johnson","Peter","Ali","Jane","Smith","Amanda","Sophia"],"State":["TX","NY","TX","NY","NY","CA","CA","TX"],"Total Score":[82,69,98,76,88,81,90,66],"Age":[20,21,24,25,20,27,26,23]}

# %%
mydf=p.DataFrame(mydata)

# %%
mydf
# Out:
#       Name State  Total Score  Age
# 0    Harry    TX           82   20
# 1  Johnson    NY           69   21
# 2    Peter    TX           98   24
# 3      Ali    NY           76   25
# 4     Jane    NY           88   20
# 5    Smith    CA           81   27
# 6   Amanda    CA           90   26
# 7   Sophia    TX           66   23

# %%
a=mydf.groupby("State")[["Total Score","Age"]].mean() 
a# "State" is the key column. Note: the key column become the row header in the grouped dataframe
# Out:
#        Total Score        Age
# State
# CA       85.500000  26.500000
# NY       77.666667  22.000000
# TX       82.000000  22.333333

# %%
b=a.reset_index()
b
# Out:
#   State  Total Score        Age
# 0    CA    85.500000  26.500000
# 1    NY    77.666667  22.000000
# 2    TX    82.000000  22.333333

# %% [markdown]
# # 2. date and time

# %%
timerange = p.DataFrame() ## an empty dataframe

# %%
timerange

# %%
# create a column and fill it with date and time data generated by date_range() function
timerange['Date and time'] = p.date_range(start='10/6/2021 10:00:32', end='12/7/2021 14:21:00', freq ='H') ## freq 'min','S','D','M','Y'
timerange

# %%
timerange2=p.DataFrame()
timerange2['date and time']=p.date_range('10/6/2021 19:21:34',periods=100,freq='H')
timerange2

# %%
timerange2.loc[4:10]

# %%
timerange2['date and time'].dt.minute# day, month, hour, minute

# %% [markdown]
# # 3. Exporting dataframes

# %% [markdown]
# ## saving dataframe as csv

# %%
mydata={"Name":["Harry","Johnson","Peter","Ali","Jane","Smith","Amanda","Sophia"],"State":["TX","NY","TX","NY",n.NaN,"CA","CA",n.NaN],"Total Score":[82,69,98,76,88,81,90,66],"Age":[20,21,24,25,20,27,26,23]}
df=p.DataFrame(mydata)

# %%
df
# Out:
#       Name State  Total Score  Age
# 0    Harry    TX           82   20
# 1  Johnson    NY           69   21
# 2    Peter    TX           98   24
# 3      Ali    NY           76   25
# 4     Jane   NaN           88   20
# 5    Smith    CA           81   27
# 6   Amanda    CA           90   26
# 7   Sophia   NaN           66   23

# %%
df.to_csv('mydata_file.csv')  ## go to home directory nd open the csv file to check

# %%
df1=p.read_csv("mydata_file.csv")
df1
# Out:
#    Unnamed: 0     Name State  Total Score  Age
# 0           0    Harry    TX           82   20
# 1           1  Johnson    NY           69   21
# 2           2    Peter    TX           98   24
# 3           3      Ali    NY           76   25
# 4           4     Jane   NaN           88   20
# 5           5    Smith    CA           81   27
# 6           6   Amanda    CA           90   26
# 7           7   Sophia   NaN           66   23

# %%
df1=p.read_csv("mydata_file.csv",usecols=["Name","State","Total Score","Age"],index_col="Name")
df1
# Out:
#         State  Total Score  Age
# Name
# Harry      TX           82   20
# Johnson    NY           69   21
# Peter      TX           98   24
# Ali        NY           76   25
# Jane      NaN           88   20
# Smith      CA           81   27
# Amanda     CA           90   26
# Sophia    NaN           66   23

# %% [markdown]
# ## convert dataframe to array

# %%
dfarray=df.to_numpy()

# %%
dfarray
# Out:
# array([['Harry', 'TX', 82, 20],
#        ['Johnson', 'NY', 69, 21],
#        ['Peter', 'TX', 98, 24],
#        ['Ali', 'NY', 76, 25],
#        ['Jane', nan, 88, 20],
#        ['Smith', 'CA', 81, 27],
#        ['Amanda', 'CA', 90, 26],
#        ['Sophia', nan, 66, 23]], dtype=object)

# %%
dfarray.ndim
# Out:
# 2

# %%
dfarray_score=df[['Total Score',"Age"]].to_numpy()

# %%
dfarray_score
# Out:
# array([[82, 20],
#        [69, 21],
#        [98, 24],
#        [76, 25],
#        [88, 20],
#        [81, 27],
#        [90, 26],
#        [66, 23]], dtype=int64)

# %%
reconv_df=p.DataFrame(dfarray)

# %%
reconv_df  ## note: it doesnt contain the column titles
# Out:
#          0    1   2   3
# 0    Harry   TX  82  20
# 1  Johnson   NY  69  21
# 2    Peter   TX  98  24
# 3      Ali   NY  76  25
# 4     Jane  NaN  88  20
# 5    Smith   CA  81  27
# 6   Amanda   CA  90  26
# 7   Sophia  NaN  66  23

# %% [markdown]
# ## Few more things...

# %%
df
# Out:
#       Name State  Total Score  Age
# 0    Harry    TX           82   20
# 1  Johnson    NY           69   21
# 2    Peter    TX           98   24
# 3      Ali    NY           76   25
# 4     Jane   NaN           88   20
# 5    Smith    CA           81   27
# 6   Amanda    CA           90   26
# 7   Sophia   NaN           66   23

# %%
# find the number of unique values in a column
df["State"].nunique()
# Out:
# 3

# %%
# display the unique values in a column
df["State"].unique()
# Out:
# array(['TX', 'NY', nan, 'CA'], dtype=object)

# %%
# see whether and where are the nulls in a column
x=df["State"].isna() #also isnull()
x
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7     True
# Name: State, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8 non-null      object
#  1   State        6 non-null      object
#  2   Total Score  8 non-null      int64
#  3   Age          8 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 388.0+ bytes

# %%
indices=[]
for i in range(len(x)):
    if x[i]==True:
        indices.append(i)
indices
# Out:
# [4, 7]

# %%
# count how many times each value occurs in a column
df["State"].value_counts()
# Out:
# State
# TX    2
# NY    2
# CA    2
# Name: count, dtype: int64
