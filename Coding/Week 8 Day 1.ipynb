# %%
import numpy as np

# %%
a = np.array(((1,2), (3,4)))

# %%
np.linalg.det(a)
# Out:
# -2.0000000000000004

# %%
b = np.array(((3,4),(5,6)))

# %%
a@b
# Out:
# array([[13, 16],
#        [29, 36]])

# %%
c = np.array((1,2))

# %%
b@c
# Out:
# array([11, 17])

# %%
import pickle
my_dict = {"name": "hello", "height": 1.81}

# %%
pickle.dump(my_dict, open("my_dict.pkl", "wb"))

# %%
new_dict = pickle.load(open("my_dict.pkl", "rb"))
print(new_dict)
# Out:
# {'name': 'hello', 'height': 1.81}
